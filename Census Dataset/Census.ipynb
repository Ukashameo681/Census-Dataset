# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\Muhammad Ukasha Atif\AppData\Local\Temp\ipykernel_5200\2151744951.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv(r"D:\Python life\Census Dataset\file.csv", index_col=None)

# %%
data.head(1)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
#
# [1 rows x 25 columns]

# %% [markdown]
# ### Q. 1) How will you hide the indexes of the dataframe.

# %%
data.head(1).style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_eeb91">
#   <thead>
#     <tr>
#       <th id="T_eeb91_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_eeb91_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_eeb91_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_eeb91_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_eeb91_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_eeb91_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_eeb91_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_eeb91_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_eeb91_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
#       <th id="T_eeb91_level0_col9" class="col_heading level0 col9" >Female_Workers</th>
# ...

# %% [markdown]
# ### Q. 2) How can we set the caption / heading on the dataframe.

# %%
data.head(1).style.set_caption("DataFrame for Census")
# Out:
# <style type="text/css">
# </style>
# <table id="T_65741">
#   <caption>DataFrame for Census</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65741_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_65741_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_65741_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_65741_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_65741_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_65741_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_65741_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_65741_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_65741_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
# ...

# %% [markdown]
# ### Q. 3) Show the records related with the districts - New Delhi , Lucknow , Jaipur.

# %%
data.head(1)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
#
#    Buddhists  Jains  Secondary_Education  Higher_Education  \
# 0         66     39                74948             39709
#
#    Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 0               21751          600759           178435         89679
#
# [1 rows x 25 columns]

# %%
data[(data["District_name"]=="New Delhi")|(data["District_name"]=="Lucknow")|(data["District_name"]=="Jaipur")]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# ### Q. 4) Calculate state-wise :
# A. Total number of population.
# B. Total no. of the population with different religions.

# %%
data.groupby("State_name")["Sikhs"].sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS        1286
# ANDHRA PRADESH                    40244
# ARUNACHAL PRADESH                  3287
# ASSAM                             20672
# BIHAR                             23779
# CHANDIGARH                       138329
# CHHATTISGARH                      70036
# DADRA AND NAGAR HAVELI              217
# DAMAN AND DIU                       172
# GOA                                1473
# GUJARAT                           58246
# HARYANA                         1243752
# HIMACHAL PRADESH                  79896
# JAMMU AND KASHMIR                234848
# JHARKHAND                         71422
# KARNATAKA                         28773
# KERALA                             3814
# LAKSHADWEEP                           8
# MADHYA PRADESH                   151412
# MAHARASHTRA                      223247
# MANIPUR                            1527
# MEGHALAYA                          3045
# MIZORAM                             286
# ...

# %%
data.groupby("State_name")["Christians"].sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS      80984
# ANDHRA PRADESH                 1129784
# ARUNACHAL PRADESH               418732
# ASSAM                          1165867
# BIHAR                           129247
# CHANDIGARH                        8720
# CHHATTISGARH                    490542
# DADRA AND NAGAR HAVELI            5113
# DAMAN AND DIU                     2820
# GOA                             366130
# GUJARAT                         316178
# HARYANA                          50353
# HIMACHAL PRADESH                 12646
# JAMMU AND KASHMIR                35631
# JHARKHAND                      1418608
# KARNATAKA                      1142647
# KERALA                         6141269
# LAKSHADWEEP                        317
# MADHYA PRADESH                  213282
# MAHARASHTRA                    1080073
# MANIPUR                        1179043
# MEGHALAYA                      2213027
# MIZORAM                         956331
# NAGALAND                       1739651
# ...

# %%
data.groupby("State_name")["Jains"].sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS         31
# ANDHRA PRADESH                   53849
# ARUNACHAL PRADESH                  771
# ASSAM                            25949
# BIHAR                            18914
# CHANDIGARH                        1960
# CHHATTISGARH                     61510
# DADRA AND NAGAR HAVELI            1186
# DAMAN AND DIU                      287
# GOA                               1109
# GUJARAT                         579654
# HARYANA                          52613
# HIMACHAL PRADESH                  1805
# JAMMU AND KASHMIR                 2490
# JHARKHAND                        14974
# KARNATAKA                       440280
# KERALA                            4489
# LAKSHADWEEP                         11
# MADHYA PRADESH                  567028
# MAHARASHTRA                    1400349
# MANIPUR                           1692
# MEGHALAYA                          627
# MIZORAM                            376
# NAGALAND                          2655
# ...

# %%
data.groupby("State_name")["Buddhists"].sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS        338
# ANDHRA PRADESH                   36692
# ARUNACHAL PRADESH               162815
# ASSAM                            54993
# BIHAR                            25453
# CHANDIGARH                        1160
# CHHATTISGARH                     70467
# DADRA AND NAGAR HAVELI             634
# DAMAN AND DIU                      217
# GOA                               1095
# GUJARAT                          30483
# HARYANA                           7514
# HIMACHAL PRADESH                 78659
# JAMMU AND KASHMIR               112584
# JHARKHAND                         8956
# KARNATAKA                        95710
# KERALA                            4752
# LAKSHADWEEP                         10
# MADHYA PRADESH                  216052
# MAHARASHTRA                    6531200
# MANIPUR                           7084
# MEGHALAYA                         9864
# MIZORAM                          93411
# NAGALAND                          6759
# ...

# %%
data.groupby("State_name")["Population"].sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       380581
# ANDHRA PRADESH                  84580777
# ARUNACHAL PRADESH                1383727
# ASSAM                           31205576
# BIHAR                          104099452
# CHANDIGARH                       1055450
# CHHATTISGARH                    25545198
# DADRA AND NAGAR HAVELI            343709
# DAMAN AND DIU                     243247
# GOA                              1458545
# GUJARAT                         60439692
# HARYANA                         25351462
# HIMACHAL PRADESH                 6864602
# JAMMU AND KASHMIR               12541302
# JHARKHAND                       32988134
# KARNATAKA                       61095297
# KERALA                          33406061
# LAKSHADWEEP                        64473
# MADHYA PRADESH                  72626809
# MAHARASHTRA                    112374333
# MANIPUR                          2855794
# MEGHALAYA                        2966889
# ...

# %% [markdown]
# ### Q. 5) How many Male Workers were there in Maharashtra state ?

# %%
data[data["State_name"] == "MAHARASHTRA"]["Male_Workers"].sum()
# Out:
# 32616875

# %% [markdown]
# ### Q. 6) How to set a column as index of the dataframe ?

# %%
data.set_index("District_code")
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %% [markdown]
# ### Q. 7a) Add a Suffix to the column names.

# %%
data.add_suffix("index")
# Out:
#      District_codeindex              State_nameindex  \
# 0                     1            JAMMU AND KASHMIR
# 1                     2            JAMMU AND KASHMIR
# 2                     3            JAMMU AND KASHMIR
# 3                     4            JAMMU AND KASHMIR
# 4                     5            JAMMU AND KASHMIR
# ..                  ...                          ...
# 635                 636                  PONDICHERRY
# 636                 637                  PONDICHERRY
# 637                 638  ANDAMAN AND NICOBAR ISLANDS
# 638                 639  ANDAMAN AND NICOBAR ISLANDS
# 639                 640  ANDAMAN AND NICOBAR ISLANDS
#
#             District_nameindex  Populationindex  Maleindex  Femaleindex  \
# 0                      Kupwara           870354     474190       396164
# 1                       Badgam           753745     398041       355704
# 2                  Leh(Ladakh)           133487      78971        54516
# ...

# %% [markdown]
# ### Q. 7b) Add a Prefix to the column names.

# %%
data.add_prefix("index_0")
# Out:
#      index_0District_code            index_0State_name  \
# 0                       1            JAMMU AND KASHMIR
# 1                       2            JAMMU AND KASHMIR
# 2                       3            JAMMU AND KASHMIR
# 3                       4            JAMMU AND KASHMIR
# 4                       5            JAMMU AND KASHMIR
# ..                    ...                          ...
# 635                   636                  PONDICHERRY
# 636                   637                  PONDICHERRY
# 637                   638  ANDAMAN AND NICOBAR ISLANDS
# 638                   639  ANDAMAN AND NICOBAR ISLANDS
# 639                   640  ANDAMAN AND NICOBAR ISLANDS
#
#           index_0District_name  index_0Population  index_0Male  index_0Female  \
# 0                      Kupwara             870354       474190         396164
# 1                       Badgam             753745       398041         355704
# ...
